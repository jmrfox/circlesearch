# %%
from circlesearch.graph import ArrangementGraph
import networkx as nx

parent = {
    1: None,
    2: 1,
    3: None,
}

# intersections = {(1, 2), (1, 3), (2, 3)}

# cyclic_orders = {
#     1: [(2, 0), (3, 0), (2, 1), (3, 1)],
#     2: [(1, 0), (3, 0), (1, 1), (3, 1)],
#     3: [(1, 0), (2, 0), (1, 1), (2, 1)],
# }

intersections = {(1,3)}

cyclic_orders = {1: [(3, 0), (3, 1)], 2: [], 3: [(1, 0), (1, 1)]}

G = ArrangementGraph(parent=parent, intersections=intersections, cyclic_orders=cyclic_orders)
G.print_summary()
G.draw()
# Out:
# ...
#   Arrangement Graph Summary
# ...
#   Vertices: 5    Edges: 9    Components: 1
#   Intersecting pairs (1): (1,3)
#   Containment (child -> parent):
#     circle 1 (root)
#     circle 2 inside circle 1
#     circle 3 (root)
#   Cyclic orders:
#     circle 1: (3,0) -> (3,1)
#     circle 2: (no intersections)
#     circle 3: (1,0) -> (1,1)
#   Containment edges (1):
#     C2 -> C1
#   Incidence edges (4):
#     C1 -> X1_3_0
#     C1 -> X1_3_1
#     C3 -> X1_3_0
#     C3 -> X1_3_1
#   Arc edges (4):
#     X1_3_0 -> X1_3_1  [circle 1]
#     X1_3_0 -> X1_3_1  [circle 3]
#     X1_3_1 -> X1_3_0  [circle 1]
#     X1_3_1 -> X1_3_0  [circle 3]
# ...

# %%
parent = {
    1: None,
    2: None,
}

intersections = {(1, 2)}

cyclic_orders = {
    1: [(2, 0), (2, 1)],
    2: [(1, 0), (1, 1)],
}

G = ArrangementGraph(
    parent=parent, intersections=intersections, cyclic_orders=cyclic_orders
)
G.print_summary()
G.draw()
# Out:
# ...
#   Arrangement Graph Summary
# ...
#   Vertices: 4    Edges: 8    Components: 1
#   Intersecting pairs (1): (1,2)
#   Containment (child -> parent):
#     circle 1 (root)
#     circle 2 (root)
#   Cyclic orders:
#     circle 1: (2,0) -> (2,1)
#     circle 2: (1,0) -> (1,1)
#   Incidence edges (4):
#     C1 -> X1_2_0
#     C1 -> X1_2_1
#     C2 -> X1_2_0
#     C2 -> X1_2_1
#   Arc edges (4):
#     X1_2_0 -> X1_2_1  [circle 1]
#     X1_2_0 -> X1_2_1  [circle 2]
#     X1_2_1 -> X1_2_0  [circle 1]
#     X1_2_1 -> X1_2_0  [circle 2]
# ...
